# %% [markdown]
# Dendrology is the study of trees. A critical aspect of this study is identification: the ability to look at a tree (or parts of one) and identify the family or species of the tree. Leaves are often the most easily recognizable features of trees. The goal here is to identify a tree species from a picture of its leaf.
#
# That was the goal of Leafsnap (http://leafsnap.com/dataset/), a project to build an app with this feature. This notebook will use the dataset provided by Leafsnap's developers, consisting of roughly 23,000 high-quality leaf images taken in the same composition.
#
# ---
#
# We'll start with data cleaning.
#
# Intraspecific variation -- the variation between individuals in a species -- is very high in leaves. Some may have shape differences, but shape is generally reliable. Color or venation patterns are too unreliable, with signficicant variation between individual leaves due to photographic quality, possible illnesses, or even time of year. It'd be useful if the dataset could just consist of the shapes of leaves, with these unreliable features removed. The developers of Leafsnap came to this conclusion, and designed an image segmentation algorithm. They've included a dataset of segmented leaf images.
#
# There's an issue though: roughly half of that dataset is bad data, errors of their algorithm. Manually removing these errors would be tedious, so I've built and applied a classifier to remove them automatically. The details of the process can be found here: https://github.com/MSDR/Projects-in-ML-and-AI/blob/main/HW5/Homework_5_Data_Cleaning.ipynb, with the resulting dataset saved as dataset/segmented-justleaves.
#
# NOTE: The data cleaning notebook has an error itself. The list of classes was created by getting all file/directory names in datasets/segmented, which included the labels files themselves: labels.csv and labels.txt. Because of this, all species with names coming phoenetically after 'labels.txt' were put into the wrong folder. This error has been fixed and applied to the dataset used here.
#
# ---
#
# Though the segmented data's errors have now been cleaned out, there remains an issue: class imbalance and poor representation of some classes.
#
# Segmentation errors affected some classes more severely than others. For example, many pine species' segmentations were 100% error.
# To help resolve this issue, any classes with less than 20 examples have been removed, a total of 53/185. The original dataset is still available as dataset/segmented-justleaves, while the balanced dataset is available as dataset/segmented-justleaves-balanced.
#
# ---
#
# Let's load this data and look at a sample:

# %%
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
# Out:
# Num GPUs Available:  0

# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras

#some hyperparameters:
imageSize = (64, 64)
imageSizeFlat = imageSize[0]*imageSize[1]
batchSize = 64

#load full leaf dataset
leafDir = "dataset/segmented-justleaves-balanced"
leavesData = tf.keras.preprocessing.image_dataset_from_directory(leafDir, labels='inferred', color_mode='grayscale', image_size=imageSize, batch_size=batchSize, shuffle=True)

#yield some information from dataset
leavesSize = leavesData.cardinality().numpy()
print("Dataset split into", leavesSize, "batches of", batchSize, "examples each.")

#create a list of species labels
#the index of each label here corresponds to the integer-value label keras inferred
labelText = open("dataset/labels-balanced.txt", "r")
speciesLabels = labelText.read()
speciesLabels = speciesLabels.split('\n')

#plot a sample of the dataset
plt.figure(figsize=(12, 11))
displayCount = 0
for images, labels in leavesData.take(2):
    for i in range(batchSize):
        ax = plt.subplot(5, 5, displayCount + 1)
        plt.imshow(np.squeeze(images[i].numpy().astype("uint8")), cmap='gray', vmin=0, vmax=255)
        plt.title(speciesLabels[int(labels[i])])
        plt.axis("off")    

        displayCount += 1
        if(displayCount==25):
            break
    if(displayCount==25):
        break
# Out:
# Found 10467 files belonging to 132 classes.
# Dataset split into 164 batches of 64 examples each.

# %%
# classCounts = {i : 0 for i in range(len(speciesLabels))}
# n = 0
# for image, label in leavesData.as_numpy_iterator():
#   for label in labels: #iterate through the batch
#     classCounts[int(label)] += 1
#     n += 1
#     if n%1000==0 or (n%100==0 and n<1000):
#       print(n) 

#     if(n<50):
#       print("")
  
  

# classCounts

# %%
leavesSplit = [0.8, 0.1, 0.1] #train/dev/test split ratios

#split the data
leavesTrainSize = int(leavesSplit[0] * leavesSize)
leavesDevSize = int(leavesSplit[1] * leavesSize)
leavesTrainSet = leavesData.take(leavesTrainSize)    
leavesDevSet = leavesData.skip(leavesTrainSize).take(leavesDevSize)
leavesTestSet = leavesData.skip(leavesTrainSize).skip(leavesDevSize)

print("At", batchSize, "examples per batch:")
print("> Train set example count:", leavesTrainSet.cardinality().numpy()*batchSize)
print("> Dev set example count:  ", leavesDevSet.cardinality().numpy()*batchSize)
print("> Test set example count: ", leavesTestSet.cardinality().numpy()*batchSize)
# Out:
# At 64 examples per batch:
# > Train set example count: 8384
# > Dev set example count:   1024
# > Test set example count:  1088

# %%
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dense, Flatten, Normalization

CNN = keras.Sequential([
    Normalization(),
    Conv2D(6, 5, input_shape=(imageSize[0], imageSize[1], 1)),
    MaxPooling2D(pool_size=2),
    Conv2D(16, 5),
    MaxPooling2D(pool_size=2),
    Flatten(),
    Dense(512, activation="tanh"),
    Dense(256, activation="tanh"),
    Dense(len(speciesLabels), activation="softmax")
])

#compile the model
CNN.compile(
  'adam',
  loss='sparse_categorical_crossentropy', #this loss function is easily compatible with the dataset intake function used (tf.keras.preprocessing.image_dataset_from_directory())
  metrics=['accuracy'],
)

# %%
#trains the model, returning a list of validation accuracy measures at the end of each epoch 
def trainModel(model, epochs, trainSet, devSet, earlyStopping=1, verbose=0):
  accLog = []
  valAccLog = []

  #train the model
  for e in range(epochs):
    model.fit(trainSet, epochs=1, validation_data=devSet, verbose=verbose)

    #record validation accuracy
    accLog += [ex for ex in model.history.history['accuracy']]
    valAccLog += [ex for ex in model.history.history['val_accuracy']]

    #implementation of early stopping
    if(e != epochs-1 and accLog[len(accLog)-1] >= earlyStopping): 
      print("==> Validation accuracy exceeded (or met) %d%%, early stopping initiated at epoch %d." % (earlyStopping*100, e+1))
      break 

  return (accLog, valAccLog)

def plotModelResults(logs, modelName, epochs):
  #graph accuracies
  plt.xlabel("Epochs")
  plt.xticks(range(0,epochs, int(epochs/10)))
  plt.ylabel("Accuracy")
  plt.title(modelName + " Accuracy throughout Training")
  plt.plot(logs[0], "c", label="Accuracy") 
  plt.plot(logs[1], "b", label="Val. Accuracy")
  plt.legend()
  plt.show()

# %%
leavesTrainSet = leavesTrainSet.prefetch(tf.data.experimental.AUTOTUNE)
leavesDevSet = leavesDevSet.prefetch(tf.data.experimental.AUTOTUNE)
leavesTestSet = leavesTestSet.prefetch(tf.data.experimental.AUTOTUNE)

# %%
cnnEpochs = 50

#run 10 models
cnnTrainingLogs = trainModel(CNN, cnnEpochs, leavesTrainSet, leavesDevSet, earlyStopping=0.90, verbose=1)
# Out:
# 131/131 [==============================] - 7s 48ms/step - loss: 4.3159 - accuracy: 0.0705 - val_loss: 3.8307 - val_accuracy: 0.1152
# 131/131 [==============================] - 6s 48ms/step - loss: 3.6232 - accuracy: 0.1567 - val_loss: 3.4178 - val_accuracy: 0.2197
# 131/131 [==============================] - 6s 48ms/step - loss: 3.3828 - accuracy: 0.1950 - val_loss: 3.3568 - val_accuracy: 0.1992
# 131/131 [==============================] - 6s 49ms/step - loss: 3.2135 - accuracy: 0.2215 - val_loss: 3.1636 - val_accuracy: 0.2490
# 131/131 [==============================] - 6s 48ms/step - loss: 3.0684 - accuracy: 0.2536 - val_loss: 3.1311 - val_accuracy: 0.2451
# 131/131 [==============================] - 6s 48ms/step - loss: 2.9685 - accuracy: 0.2663 - val_loss: 2.9998 - val_accuracy: 0.2773
# 131/131 [==============================] - 6s 49ms/step - loss: 2.8800 - accuracy: 0.2914 - val_loss: 2.9684 - val_accuracy: 0.2744
# 131/131 [==============================] - 7s 50ms/step - loss: 2.8203 - accuracy: 0.3012 - val_loss: 2.9910 - val_accuracy: 0.2744
# 131/131 [==============================] - 7s 50ms/step - loss: 2.7561 - accuracy: 0.3069 - val_loss: 2.8241 - val_accuracy: 0.3350
# 131/131 [==============================] - 7s 49ms/step - loss: 2.6255 - accuracy: 0.3415 - val_loss: 2.7964 - val_accuracy: 0.3193
# 131/131 [==============================] - 6s 48ms/step - loss: 2.5531 - accuracy: 0.3467 - val_loss: 2.8628 - val_accuracy: 0.3135
# 131/131 [==============================] - 6s 47ms/step - loss: 2.5234 - accuracy: 0.3531 - val_loss: 2.8917 - val_accuracy: 0.3057
# 131/131 [==============================] - 7s 49ms/step - loss: 2.5028 - accuracy: 0.3587 - val_loss: 2.7331 - val_accuracy: 0.3281
# 131/131 [==============================] - 6s 48ms/step - loss: 2.4438 - accuracy: 0.3668 - val_loss: 2.7166 - val_accuracy: 0.3418
# 131/131 [==============================] - 6s 49ms/step - loss: 2.3574 - accuracy: 0.3901 - val_loss: 2.6915 - val_accuracy: 0.3525
# 131/131 [==============================] - 6s 48ms/step - loss: 2.3316 - accuracy: 0.3930 - val_loss: 2.7520 - val_accuracy: 0.3340
# 131/131 [==============================] - 7s 49ms/step - loss: 2.2681 - accuracy: 0.4005 - val_loss: 2.6142 - val_accuracy: 0.3525
# 131/131 [==============================] - 6s 49ms/step - loss: 2.2242 - accuracy: 0.4224 - val_loss: 2.7227 - val_accuracy: 0.3262
# 131/131 [==============================] - 6s 49ms/step - loss: 2.2094 - accuracy: 0.4265 - val_loss: 2.5775 - val_accuracy: 0.3779
# 131/131 [==============================] - 6s 49ms/step - loss: 2.1376 - accuracy: 0.4420 - val_loss: 2.6888 - val_accuracy: 0.3496
# 131/131 [==============================] - 6s 49ms/step - loss: 2.1250 - accuracy: 0.4326 - val_loss: 2.6697 - val_accuracy: 0.3545
# 131/131 [==============================] - 6s 49ms/step - loss: 2.0714 - accuracy: 0.4493 - val_loss: 2.5534 - val_accuracy: 0.3838
# 131/131 [==============================] - 6s 48ms/step - loss: 2.0508 - accuracy: 0.4561 - val_loss: 2.5079 - val_accuracy: 0.3838
# 131/131 [==============================] - 6s 49ms/step - loss: 2.0018 - accuracy: 0.4660 - val_loss: 2.5548 - val_accuracy: 0.3604
# 131/131 [==============================] - 7s 54ms/step - loss: 1.9362 - accuracy: 0.4773 - val_loss: 2.5331 - val_accuracy: 0.3760
# 131/131 [==============================] - 7s 49ms/step - loss: 1.9710 - accuracy: 0.4673 - val_loss: 2.7403 - val_accuracy: 0.3164
# 131/131 [==============================] - 7s 50ms/step - loss: 1.9057 - accuracy: 0.4896 - val_loss: 2.4952 - val_accuracy: 0.3809
# 131/131 [==============================] - 7s 51ms/step - loss: 1.8686 - accuracy: 0.4980 - val_loss: 2.6398 - val_accuracy: 0.3750
# 131/131 [==============================] - 6s 46ms/step - loss: 1.8400 - accuracy: 0.5037 - val_loss: 2.6540 - val_accuracy: 0.3691
# 131/131 [==============================] - 6s 47ms/step - loss: 1.9316 - accuracy: 0.4772 - val_loss: 2.6070 - val_accuracy: 0.3848
# 131/131 [==============================] - 6s 46ms/step - loss: 1.7763 - accuracy: 0.5192 - val_loss: 2.4767 - val_accuracy: 0.4121
# 131/131 [==============================] - 6s 47ms/step - loss: 1.7076 - accuracy: 0.5423 - val_loss: 2.4683 - val_accuracy: 0.3809
# 131/131 [==============================] - 6s 47ms/step - loss: 1.7226 - accuracy: 0.5279 - val_loss: 2.5417 - val_accuracy: 0.3867
# 131/131 [==============================] - 6s 47ms/step - loss: 1.6618 - accuracy: 0.5458 - val_loss: 2.5346 - val_accuracy: 0.3975
# 131/131 [==============================] - 6s 47ms/step - loss: 1.7743 - accuracy: 0.5134 - val_loss: 2.6604 - val_accuracy: 0.3643
# 131/131 [==============================] - 7s 50ms/step - loss: 1.6968 - accuracy: 0.5382 - val_loss: 2.4583 - val_accuracy: 0.4102
# 131/131 [==============================] - 6s 47ms/step - loss: 1.6220 - accuracy: 0.5561 - val_loss: 2.4647 - val_accuracy: 0.3936
# 131/131 [==============================] - 6s 47ms/step - loss: 1.6568 - accuracy: 0.5408 - val_loss: 2.5097 - val_accuracy: 0.3936
# 131/131 [==============================] - 6s 48ms/step - loss: 1.6505 - accuracy: 0.5489 - val_loss: 2.4881 - val_accuracy: 0.4092
# 131/131 [==============================] - 6s 47ms/step - loss: 1.5597 - accuracy: 0.5723 - val_loss: 2.4297 - val_accuracy: 0.4170
# 131/131 [==============================] - 6s 47ms/step - loss: 1.5840 - accuracy: 0.5609 - val_loss: 2.4347 - val_accuracy: 0.4346
# 131/131 [==============================] - 6s 47ms/step - loss: 1.5865 - accuracy: 0.5563 - val_loss: 2.3384 - val_accuracy: 0.4463
# 131/131 [==============================] - 6s 47ms/step - loss: 1.6017 - accuracy: 0.5559 - val_loss: 2.3560 - val_accuracy: 0.4229
# 131/131 [==============================] - 6s 47ms/step - loss: 1.5381 - accuracy: 0.5726 - val_loss: 2.4488 - val_accuracy: 0.4160
# 131/131 [==============================] - 6s 47ms/step - loss: 1.4471 - accuracy: 0.6052 - val_loss: 2.3340 - val_accuracy: 0.4404
# 131/131 [==============================] - 6s 49ms/step - loss: 1.5011 - accuracy: 0.5881 - val_loss: 2.4443 - val_accuracy: 0.4092
# 131/131 [==============================] - 6s 47ms/step - loss: 1.4505 - accuracy: 0.5948 - val_loss: 2.5060 - val_accuracy: 0.4150
# 131/131 [==============================] - 6s 47ms/step - loss: 1.4519 - accuracy: 0.5983 - val_loss: 2.4676 - val_accuracy: 0.4111
# 131/131 [==============================] - 6s 47ms/step - loss: 1.5522 - accuracy: 0.5650 - val_loss: 2.4147 - val_accuracy: 0.4424
# 131/131 [==============================] - 6s 47ms/step - loss: 1.3894 - accuracy: 0.6075 - val_loss: 2.4663 - val_accuracy: 0.4209

# %%
plotModelResults(cnnTrainingLogs, "CNN", cnnEpochs)

# %%
CNN.evaluate(leavesTestSet)
# Out:
# 17/17 [==============================] - 2s 11ms/step - loss: 2.6738 - accuracy: 0.3872
# [2.6737895011901855, 0.38715770840644836]

# %%
mobileNet = keras.Sequential([
    Normalization(),
    tf.keras.applications.MobileNet(input_shape=(imageSize[0], imageSize[1], 1), classes=len(speciesLabels), weights=None)
])

mobileNet.compile(
    optimizer="adam",
    loss='sparse_categorical_crossentropy', #this loss function is easily compatible with the dataset intake function used (tf.keras.preprocessing.image_dataset_from_directory())
    metrics=['accuracy']
)

# %%
mobileNetEpochs = 50
mobileNetLogs = trainModel(mobileNet, mobileNetEpochs, leavesTrainSet, leavesDevSet, earlyStopping=0.90, verbose=1)
# Out:
# 131/131 [==============================] - 33s 239ms/step - loss: 4.3245 - accuracy: 0.0651 - val_loss: 5.2081 - val_accuracy: 0.0088
# 131/131 [==============================] - 31s 237ms/step - loss: 3.5311 - accuracy: 0.1535 - val_loss: 5.9862 - val_accuracy: 0.0068
# 131/131 [==============================] - 31s 233ms/step - loss: 3.1341 - accuracy: 0.2117 - val_loss: 6.2266 - val_accuracy: 0.0059
# 131/131 [==============================] - 31s 236ms/step - loss: 2.7900 - accuracy: 0.2752 - val_loss: 6.7789 - val_accuracy: 0.0059
# 131/131 [==============================] - 30s 232ms/step - loss: 2.5512 - accuracy: 0.3261 - val_loss: 5.6952 - val_accuracy: 0.0283
# 131/131 [==============================] - 30s 232ms/step - loss: 2.2989 - accuracy: 0.3788 - val_loss: 2.9107 - val_accuracy: 0.2686
# 131/131 [==============================] - 30s 232ms/step - loss: 2.1262 - accuracy: 0.4080 - val_loss: 3.5772 - val_accuracy: 0.2197
# 131/131 [==============================] - 30s 232ms/step - loss: 1.9434 - accuracy: 0.4536 - val_loss: 4.2779 - val_accuracy: 0.1914
# 131/131 [==============================] - 31s 239ms/step - loss: 1.7943 - accuracy: 0.4899 - val_loss: 4.9029 - val_accuracy: 0.1504
# 131/131 [==============================] - 31s 234ms/step - loss: 1.6815 - accuracy: 0.5136 - val_loss: 4.4684 - val_accuracy: 0.2236
# 131/131 [==============================] - 31s 233ms/step - loss: 1.5855 - accuracy: 0.5428 - val_loss: 3.6991 - val_accuracy: 0.3008
# 131/131 [==============================] - 30s 231ms/step - loss: 1.4433 - accuracy: 0.5766 - val_loss: 4.3230 - val_accuracy: 0.2510
# 131/131 [==============================] - 31s 235ms/step - loss: 1.3081 - accuracy: 0.6094 - val_loss: 4.0814 - val_accuracy: 0.2549
# 131/131 [==============================] - 30s 231ms/step - loss: 1.2214 - accuracy: 0.6344 - val_loss: 3.6074 - val_accuracy: 0.2969
# 131/131 [==============================] - 31s 234ms/step - loss: 1.1275 - accuracy: 0.6657 - val_loss: 3.0557 - val_accuracy: 0.3994
# 131/131 [==============================] - 30s 231ms/step - loss: 1.0643 - accuracy: 0.6792 - val_loss: 3.8150 - val_accuracy: 0.2998
# 131/131 [==============================] - 31s 236ms/step - loss: 0.9373 - accuracy: 0.7140 - val_loss: 3.2264 - val_accuracy: 0.4170
# 131/131 [==============================] - 30s 231ms/step - loss: 0.8745 - accuracy: 0.7350 - val_loss: 3.5053 - val_accuracy: 0.3945
# 131/131 [==============================] - 31s 235ms/step - loss: 0.8751 - accuracy: 0.7281 - val_loss: 3.3257 - val_accuracy: 0.4023
# 131/131 [==============================] - 30s 232ms/step - loss: 0.7706 - accuracy: 0.7600 - val_loss: 3.4527 - val_accuracy: 0.4023
# 131/131 [==============================] - 31s 238ms/step - loss: 0.7165 - accuracy: 0.7786 - val_loss: 2.6657 - val_accuracy: 0.4922
# 131/131 [==============================] - 32s 245ms/step - loss: 0.6622 - accuracy: 0.7921 - val_loss: 3.8648 - val_accuracy: 0.3516
# 131/131 [==============================] - 33s 251ms/step - loss: 0.5987 - accuracy: 0.8120 - val_loss: 2.6398 - val_accuracy: 0.4824
# 131/131 [==============================] - 32s 244ms/step - loss: 0.5485 - accuracy: 0.8254 - val_loss: 3.0585 - val_accuracy: 0.4473
# 131/131 [==============================] - 32s 244ms/step - loss: 0.5670 - accuracy: 0.8197 - val_loss: 2.9010 - val_accuracy: 0.5107
# 131/131 [==============================] - 32s 244ms/step - loss: 0.4957 - accuracy: 0.8424 - val_loss: 2.5693 - val_accuracy: 0.5547
# 131/131 [==============================] - 32s 245ms/step - loss: 0.4602 - accuracy: 0.8523 - val_loss: 2.8147 - val_accuracy: 0.5264
# 131/131 [==============================] - 32s 240ms/step - loss: 0.4860 - accuracy: 0.8463 - val_loss: 3.6658 - val_accuracy: 0.4268
# 131/131 [==============================] - 31s 234ms/step - loss: 0.4894 - accuracy: 0.8403 - val_loss: 3.1758 - val_accuracy: 0.4902
# 131/131 [==============================] - 31s 234ms/step - loss: 0.4383 - accuracy: 0.8545 - val_loss: 3.0765 - val_accuracy: 0.5225
# 131/131 [==============================] - 31s 234ms/step - loss: 0.3635 - accuracy: 0.8849 - val_loss: 2.7720 - val_accuracy: 0.5547
# 131/131 [==============================] - 32s 246ms/step - loss: 0.3459 - accuracy: 0.8900 - val_loss: 4.9373 - val_accuracy: 0.3613
# 131/131 [==============================] - 31s 234ms/step - loss: 0.3402 - accuracy: 0.8934 - val_loss: 2.7364 - val_accuracy: 0.5635
# 131/131 [==============================] - 32s 242ms/step - loss: 0.3400 - accuracy: 0.8932 - val_loss: 2.4687 - val_accuracy: 0.5957
# 131/131 [==============================] - 31s 238ms/step - loss: 0.3255 - accuracy: 0.8934 - val_loss: 2.9036 - val_accuracy: 0.5420
# 131/131 [==============================] - 31s 240ms/step - loss: 0.3263 - accuracy: 0.8937 - val_loss: 3.4639 - val_accuracy: 0.4824
# 131/131 [==============================] - 32s 241ms/step - loss: 0.3178 - accuracy: 0.8966 - val_loss: 2.5860 - val_accuracy: 0.5908
# 131/131 [==============================] - 31s 235ms/step - loss: 0.2897 - accuracy: 0.9040 - val_loss: 2.9499 - val_accuracy: 0.5469
# ==> Validation accuracy exceeded (or met) 90%, early stopping initiated at epoch 38.

# %%
mobileNet.evaluate(leavesTestSet)
# Out:
# 17/17 [==============================] - 2s 56ms/step - loss: 3.8387 - accuracy: 0.4523
# [3.838655948638916, 0.45231351256370544]

# %%
plotModelResults(mobileNetLogs, "MobileNet", mobileNetEpochs)

# %%
from tensorflow.keras.layers import RandomFlip, RandomRotation, RandomTranslation

data_augmentation = tf.keras.Sequential([
    RandomFlip("horizontal_and_vertical"),
    RandomRotation(0.2),
    RandomTranslation(height_factor=(-0.1, 0.1), width_factor=(-0.1, 0.1))
])

# %%
leafExample = leavesData.as_numpy_iterator().next()

plt.figure(figsize=(10, 10))
for i in range(16):
    augLeaf = data_augmentation(leafExample[0])
    plt.subplot(4, 4, i+1)
    plt.imshow(augLeaf[0], cmap='gray', vmin=0, vmax=255)
    plt.axis("off")

# %%
augCNN = keras.Sequential([
    data_augmentation,
    Normalization(),
    Conv2D(6, 5, input_shape=(imageSize[0], imageSize[1], 1)),
    MaxPooling2D(pool_size=2),
    Conv2D(16, 5),
    MaxPooling2D(pool_size=2),
    Flatten(),
    Dense(512, activation="tanh"),
    Dense(256, activation="tanh"),
    Dense(len(speciesLabels), activation="softmax")
])

#compile the model
CNN.compile(
  'adam',
  loss='sparse_categorical_crossentropy',
  metrics=['accuracy'],
)
